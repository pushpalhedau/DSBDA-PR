# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris = pd.read_csv('C:/Users/HARSH PATIL/Desktop/dataset/5-8-13-14.iris.csv')
iris
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
iris.head(20)
# Out:
#     sepal.length  sepal.width  petal.length  petal.width variety
# 0            5.1          3.5           1.4          0.2  Setosa
# 1            4.9          3.0           1.4          0.2  Setosa
# 2            4.7          3.2           1.3          0.2  Setosa
# 3            4.6          3.1           1.5          0.2  Setosa
# 4            5.0          3.6           1.4          0.2  Setosa
# 5            5.4          3.9           1.7          0.4  Setosa
# 6            4.6          3.4           1.4          0.3  Setosa
# 7            5.0          3.4           1.5          0.2  Setosa
# 8            4.4          2.9           1.4          0.2  Setosa
# 9            4.9          3.1           1.5          0.1  Setosa
# 10           5.4          3.7           1.5          0.2  Setosa
# 11           4.8          3.4           1.6          0.2  Setosa
# 12           4.8          3.0           1.4          0.1  Setosa
# ...

# %%
iris.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.isnull().sum()
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# variety         0
# dtype: int64

# %%
iris.columns
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %%
iris.dtypes
# Out:
# sepal.length    float64
# sepal.width     float64
# petal.length    float64
# petal.width     float64
# variety          object
# dtype: object

# %%
sns.countplot(x = iris['variety'])
# Out:
# <Axes: xlabel='variety', ylabel='count'>

# %%
sns.histplot(data=iris, x="sepal.length",hue="variety")
# Out:
# <Axes: xlabel='sepal.length', ylabel='Count'>

# %%
sns.histplot(data=iris, x="sepal.width",hue="variety")
# Out:
# <Axes: xlabel='sepal.width', ylabel='Count'>

# %%
sns.histplot(data=iris, x="petal.length",hue="variety")
# Out:
# <Axes: xlabel='petal.length', ylabel='Count'>

# %%
sns.histplot(data=iris, x="petal.width",hue="variety")
# Out:
# <Axes: xlabel='petal.width', ylabel='Count'>

# %%
# sns.set_theme(style="darkgrid")

sns.boxplot(x=iris["sepal.length"])
# Out:
# <Axes: xlabel='sepal.length'>

# %%
sns.boxplot(x=iris["sepal.width"])
# Out:
# <Axes: xlabel='sepal.width'>

# %%
sns.boxplot(x=iris["petal.length"])
# Out:
# <Axes: xlabel='petal.length'>

# %%
sns.boxplot(x=iris["petal.width"])
# Out:
# <Axes: xlabel='petal.width'>

# %%
sns.distplot(x=iris['sepal.length'])
# Out:
# C:\Users\HARSH PATIL\AppData\Local\Temp\ipykernel_8452\1126756128.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=iris['sepal.length'])
# <Axes: ylabel='Density'>

# %%
sns.distplot(x=iris['sepal.width'])
# Out:
# C:\Users\HARSH PATIL\AppData\Local\Temp\ipykernel_8452\3090655566.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=iris['sepal.width'])
# <Axes: ylabel='Density'>

# %%
sns.distplot(x=iris['petal.length'])
# Out:
# C:\Users\HARSH PATIL\AppData\Local\Temp\ipykernel_8452\2504335231.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=iris['petal.length'])
# <Axes: ylabel='Density'>

# %%
sns.distplot(x=iris['petal.width'])
# Out:
# C:\Users\HARSH PATIL\AppData\Local\Temp\ipykernel_8452\2156591106.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=iris['petal.width'])
# <Axes: ylabel='Density'>

# %%
Q1=iris['sepal.width'].quantile(0.25)
Q3=iris['sepal.width'].quantile(0.75)
IQR=Q3-Q1
print("IQR(", IQR, ") =", "Q3(", Q3, ") - Q1(", Q1, ")")
# Out:
# IQR( 0.5 ) = Q3( 3.3 ) - Q1( 2.8 )

# %%
lower_limit=Q1-(1.5*IQR)
upper_limit=Q3+(1.5*IQR)
lower_limit,upper_limit
# Out:
# (2.05, 4.05)

# %%
df_without_outliers=iris[(iris['sepal.width']>lower_limit)&(iris['sepal.width']<upper_limit)]
df_without_outliers
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [146 rows x 5 columns]

# %%
ax = sns.boxplot(x=df_without_outliers["sepal.width"])

# %%
sns.distplot(x=iris['sepal.width'])

sns.distplot(x=df_without_outliers['sepal.width'])
# Out:
# C:\Users\HARSH PATIL\AppData\Local\Temp\ipykernel_8452\1139644869.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=iris['sepal.width'])
# C:\Users\HARSH PATIL\AppData\Local\Temp\ipykernel_8452\1139644869.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.distplot(x=df_without_outliers['sepal.length'])
sns.distplot(x=df_without_outliers['sepal.width'])
sns.distplot(x=df_without_outliers['petal.length'])
sns.distplot(x=df_without_outliers['petal.width'])
# Out:
# C:\Users\HARSH PATIL\AppData\Local\Temp\ipykernel_8452\1557723813.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df_without_outliers['sepal.length'])
# C:\Users\HARSH PATIL\AppData\Local\Temp\ipykernel_8452\1557723813.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.pairplot(data= df_without_outliers, hue='variety')
